# %%
import pandas as pd
df = pd.read_excel('Sample_Data_1.xlsx')

# %%
df.head()
# Out:
#    Fam. No. Publication no Current assignees Player Type  XX Rating  \
# 0         1     Reference9               BYD         OEM          5
# 1         2    Reference10               BYD         OEM          5
# 2         3   Reference330             NIDEC     Suplier          5
# 3         4    Reference12               BYD         OEM          4
# 4         5    Reference34           DAIMLER         OEM          4
#
#    Sub-component                                   Uniqueness  \
# 0  MOTOR COOLING  Oil-cooled cooling system | Spraying device
# 1   MOTOR CASING                  Water-cooled cooling device
# 2        Winding                             Hairpin windings
# 3   MOTOR CASING                             Silencing spaces
# 4         STATOR                             Cooling channels
#
#                        Impact/Benefit AC/DC Motor Phase   ...  \
# 0          Improved cooling | Compact         NaN    NaN  ...
# 1                             Compact         NaN    NaN  ...
# 2                    Improved Cooling          AC    NaN  ...
# 3  NVH | Improved Structural Strength         NaN    NaN  ...
# 4                    Improved cooling         NaN    NaN  ...
#
#   Earliest priority date Application dates Unnamed: 27 Unnamed: 28  \
# 0             2019-04-15        2019-04-15         NaN         NaN
# 1             2019-04-15        2019-04-15         NaN         NaN
# 2             2019-10-31        2020-10-14         NaN         NaN
# 3             2019-07-16        2019-07-16         NaN         NaN
# 4             2018-08-08        2018-08-08         NaN         NaN
#
#   Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33  Unnamed: 34
# 0         NaN         NaN         NaN         NaN         NaN          NaN
# 1         NaN         NaN         NaN         NaN         NaN          NaN
# 2         NaN         NaN         NaN         NaN         NaN          NaN
# 3         NaN         NaN         NaN         NaN         NaN          NaN
# 4         NaN         NaN         NaN         NaN         NaN          NaN
#
# [5 rows x 35 columns]

# %%
df['Current assignees'].value_counts()
# Out:
# HONDA MOTOR              36
# HITACHI                  10
# FORD                     10
# DAIMLER                   9
# BYD                       8
# HYUNDAI|KIA               6
# DANA                      4
# TOYOTA                    2
# FAW                       2
# NIDEC                     2
# CONTINENTAL               2
# GM                        1
# BORGWARNER                1
# DENSO  |TOYOTA            1
# VOLKSWAGEN                1
# NISSAN                    1
# HONDA MOTOR  |HITACHI     1
# VITESCO                   1
# HYUNDAI                   1
# RENAULT  |NISSAN          1
# Name: Current assignees, dtype: int64

# %%
'HONDA MOTOR','HITACHI','FORD','DAIMLER','BYD','HYUNDAI|KIA','DANA','TOYOTA','FAW,NIDEC','CONTINENTAL','GM','BORGWARNER','DENSO  |TOYOTA','VOLKSWAGEN','NISSAN','HONDA MOTOR  |HITACHI','VITESCO','HYUNDAI','RENAULT  |NISSAN'
# Out:
# MOTOR COOLING               39
# STATOR                      17
# ROTOR                        8
# MOTOR CASING                 7
# MOTOR CONTROL                5
# MOTOR WINDING                5
# STATOR WINDING               4
# STATOR                       3
# ROTOR MAGNET                 2
# Winding                      2
# SUPPORTING MEMBER            1
# WINDINGS                     1
# MOTOR BEARING                1
# Rotor                        1
# ROTOR CORE                   1
# MOTOR COUPLING               1
# ROTOR CORE | STATOR CORE     1
# OUTPUT SHAFT                 1
# Name: Sub-component, dtype: int64

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
df['Current assignees'].value_counts()
# Out:
# HONDA MOTOR              36
# HITACHI                  10
# FORD                     10
# DAIMLER                   9
# BYD                       8
# HYUNDAI|KIA               6
# DANA                      4
# TOYOTA                    2
# FAW                       2
# NIDEC                     2
# CONTINENTAL               2
# GM                        1
# BORGWARNER                1
# DENSO  |TOYOTA            1
# VOLKSWAGEN                1
# NISSAN                    1
# HONDA MOTOR  |HITACHI     1
# VITESCO                   1
# HYUNDAI                   1
# RENAULT  |NISSAN          1
# Name: Current assignees, dtype: int64

# %%
r=df[(df['Current assignees'] == 'FORD')]["Sub-component"]
r = r.tolist()
f={}
for i in r:
    f[i]=r.count(i)
f
# Out:
# {'STATOR WINDING': 1, 'ROTOR': 2, 'MOTOR WINDING': 3, 'STATOR': 4}

# %%
hm=df[(df['Current assignees'] == 'HITACHI')]["Sub-component"]
hm = hm.tolist()
h={}
for i in hm:
    h[i]=hm.count(i)
h
# Out:
# {'MOTOR CASING': 2,
#  'STATOR': 2,
#  'ROTOR': 1,
#  'MOTOR WINDING': 1,
#  'ROTOR CORE': 1,
#  'MOTOR COOLING': 2,
#  'MOTOR CONTROL': 1}

# %%
x=input('Enter Current assignees')
if (df['Current assignees'] == 'HONDA MOTOR').any() :
        hm=df[(df['Current assignees'] == 'HONDA MOTOR')]["Sub-component"]
        hm = hm.tolist()
        y={}
        for i in l:
            y[i]=l.count(i)
        plt.bar(range(len(y)), list(y.values()), align='center')
        plt.xticks(range(len(y)), list(y.keys()))

        plt.xticks(rotation=60)
        plt.show()
# Out:
# Enter Current assigneesHONDA MOTOR

# %% [markdown]
# ##  if Current assignees is HONDA MOTOR

# %%
x=df[(df['Current assignees'] == 'HONDA MOTOR')]["Sub-component"]
type(x)
# Out:
# pandas.core.series.Series

# %%
x
# Out:
# 10     MOTOR WINDING
# 11     MOTOR COOLING
# 12     MOTOR COOLING
# 13     MOTOR CONTROL
# 14     MOTOR COOLING
# 15           STATOR
# 16             ROTOR
# 17     MOTOR COOLING
# 18     MOTOR CONTROL
# 19      OUTPUT SHAFT
# 20      ROTOR MAGNET
# 70     MOTOR COOLING
# 71    MOTOR COUPLING
# 72     MOTOR COOLING
# 73     MOTOR COOLING
# 74     MOTOR COOLING
# 75     MOTOR COOLING
# 76     MOTOR COOLING
# 77     MOTOR COOLING
# 78     MOTOR COOLING
# 79     MOTOR COOLING
# 80     MOTOR COOLING
# 81     MOTOR COOLING
# 82            STATOR
# 83            STATOR
# 84     MOTOR COOLING
# 85     MOTOR COOLING
# 86     MOTOR COOLING
# 87     MOTOR CONTROL
# 88     MOTOR COOLING
# 89     MOTOR COOLING
# 90     MOTOR COOLING
# 91     MOTOR COOLING
# 92      ROTOR MAGNET
# 93            STATOR
# 94     MOTOR CONTROL
# Name: Sub-component, dtype: object

# %%
l = x.tolist()

# %%
print(l)
# Out:
# ['MOTOR WINDING', 'MOTOR COOLING', 'MOTOR COOLING', 'MOTOR CONTROL', 'MOTOR COOLING', 'STATOR ', 'ROTOR', 'MOTOR COOLING', 'MOTOR CONTROL', 'OUTPUT SHAFT', 'ROTOR MAGNET', 'MOTOR COOLING', 'MOTOR COUPLING', 'MOTOR COOLING', 'MOTOR COOLING', 'MOTOR COOLING', 'MOTOR COOLING', 'MOTOR COOLING', 'MOTOR COOLING', 'MOTOR COOLING', 'MOTOR COOLING', 'MOTOR COOLING', 'MOTOR COOLING', 'STATOR', 'STATOR', 'MOTOR COOLING', 'MOTOR COOLING', 'MOTOR COOLING', 'MOTOR CONTROL', 'MOTOR COOLING', 'MOTOR COOLING', 'MOTOR COOLING', 'MOTOR COOLING', 'ROTOR MAGNET', 'STATOR', 'MOTOR CONTROL']

# %%
y={}
for i in l:
    y[i]=l.count(i)
print(y)
# Out:
# {'MOTOR WINDING': 1, 'MOTOR COOLING': 22, 'MOTOR CONTROL': 4, 'STATOR ': 1, 'ROTOR': 1, 'OUTPUT SHAFT': 1, 'ROTOR MAGNET': 2, 'MOTOR COUPLING': 1, 'STATOR': 3}

# %%
d= pd.DataFrame(y.items())
d
# Out:
#                 0   1
# 0   MOTOR WINDING   1
# 1   MOTOR COOLING  22
# 2   MOTOR CONTROL   4
# 3         STATOR    1
# 4           ROTOR   1
# 5    OUTPUT SHAFT   1
# 6    ROTOR MAGNET   2
# 7  MOTOR COUPLING   1
# 8          STATOR   3

# %%
import matplotlib.pyplot as plt

plt.bar(range(len(y)), list(y.values()), align='center')
plt.xticks(range(len(y)), list(y.keys()))

plt.xticks(rotation=60)
plt.show()

# %% [raw]
# df[(df['Current assignees'] == 'HONDA MOTOR') & (df['Sub-component'] == 'MOTOR COOLING')]

# %%
import matplotlib.pyplot as plt

D = {u'Label1':26, u'Label2': 17, u'Label3':30}

plt.bar(range(len(D)), list(D.values()), align='center')
plt.xticks(range(len(D)), list(D.keys()))
# # for python 2.x:
# plt.bar(range(len(D)), D.values(), align='center')  # python 2.x
# plt.xticks(range(len(D)), D.keys())  # in python 2.x

plt.show()

# %%
sns.countplot(x =y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-9ed71567f9d4> in <module>
# ----> 1 sns.countplot(x =y)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3593         raise ValueError("Cannot pass values for both `x` and `y`")
#    3594
# -> 3595     plotter = _CountPlotter(
#    3596         x, y, hue, data, order, hue_order,
#    3597         estimator, ci, n_boot, units, seed,
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     154
#     155             # Figure out the plotting orientation
# --> 156             orient = infer_orient(
#     157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in infer_orient(x, y, orient, require_numeric)
#    1302     """
#    1303
# -> 1304     x_type = None if x is None else variable_type(x)
#    1305     y_type = None if y is None else variable_type(y)
#    1306
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in variable_type(vector, boolean_type)
#    1220
#    1221     # Special-case all-na data, which is always "numeric"
# -> 1222     if pd.isna(vector).all():
#    1223         return "numeric"
#    1224
#
# AttributeError: 'bool' object has no attribute 'all'

# %%
df[df['Current assignees'] == 'HONDA MOTOR']
# Out:
#     Fam. No. Publication no Current assignees Player Type  XX Rating  \
# 10        11    Reference89       HONDA MOTOR         OEM          4
# 11        12    Reference93       HONDA MOTOR         OEM          4
# 12        13    Reference95       HONDA MOTOR         OEM          4
# 13        14   Reference118       HONDA MOTOR         OEM          4
# 14        15   Reference121       HONDA MOTOR         OEM          4
# 15        16   Reference122       HONDA MOTOR         OEM          4
# 16        17   Reference123       HONDA MOTOR         OEM          4
# 17        18   Reference124       HONDA MOTOR         OEM          4
# 18        19   Reference125       HONDA MOTOR         OEM          4
# 19        20   Reference129       HONDA MOTOR         OEM          4
# 20        21   Reference132       HONDA MOTOR         OEM          4
# 70        71    Reference90       HONDA MOTOR         OEM          3
# 71        72    Reference91       HONDA MOTOR         OEM          3
# 72        73    Reference92       HONDA MOTOR         OEM          3
# 73        74    Reference94       HONDA MOTOR         OEM          3
# 74        75    Reference96       HONDA MOTOR         OEM          3
# 75        76    Reference97       HONDA MOTOR         OEM          3
# 76        77   Reference100       HONDA MOTOR         OEM          3
# 77        78   Reference101       HONDA MOTOR         OEM          3
# 78        79   Reference102       HONDA MOTOR         OEM          3
# 79        80   Reference103       HONDA MOTOR         OEM          3
# 80        81   Reference104       HONDA MOTOR         OEM          3
# 81        82   Reference105       HONDA MOTOR         OEM          3
# 82        83   Reference106       HONDA MOTOR         OEM          3
# 83        84   Reference107       HONDA MOTOR         OEM          3
# 84        85   Reference108       HONDA MOTOR         OEM          3
# 85        86   Reference109       HONDA MOTOR         OEM          3
# 86        87   Reference110       HONDA MOTOR         OEM          3
# 87        88   Reference111       HONDA MOTOR         OEM          3
# 88        89   Reference112       HONDA MOTOR         OEM          3
# 89        90   Reference113       HONDA MOTOR         OEM          3
# 90        91   Reference114       HONDA MOTOR         OEM          3
# 91        92   Reference117       HONDA MOTOR         OEM          3
# 92        93   Reference120       HONDA MOTOR         OEM          3
# 93        94   Reference127       HONDA MOTOR         OEM          3
# 94        95   Reference131       HONDA MOTOR         OEM          3
#
#      Sub-component                                         Uniqueness  \
# 10   MOTOR WINDING                                   Hairpin windings
# 11   MOTOR COOLING                    cooling motor using HVAC system
# 12   MOTOR COOLING                                 Refrigerant filter
# 13   MOTOR CONTROL    Rotor power control based on magnet temperature
# 14   MOTOR COOLING  rotor and stator refrigerant flow control base...
# 15         STATOR                             Sound absorbing element
# 16           ROTOR                            Rotor with ferrite core
# 17   MOTOR COOLING                       Rotor having cooling passage
# 18   MOTOR CONTROL               Current control based on motor state
# 19    OUTPUT SHAFT                                     Torque sensing
# 20    ROTOR MAGNET                                   Magnet Structure
# 70   MOTOR COOLING                      Stator having cooling Passage
# 71  MOTOR COUPLING              Fastening/releasing member for shafts
# 72   MOTOR COOLING  Coolant supplied to upper body having conducti...
# 73   MOTOR COOLING                              Alcohol spraying unit
# 74   MOTOR COOLING  Rotor cooling system having closable cooling p...
# 75   MOTOR COOLING         Rotor having guide portion for refrigerant
# 76   MOTOR COOLING                         Rotor with cooling passage
# 77   MOTOR COOLING                                   Non-woven Filter
# 78   MOTOR COOLING                       Rotor having cooling passage
# 79   MOTOR COOLING                       Rotor having cooling passage
# 80   MOTOR COOLING                       Rotor having cooling passage
# 81   MOTOR COOLING                       Rotor having cooling passage
# 82          STATOR                                Stator having pores
# 83          STATOR      Insulating sheet between conductor and stator
# 84   MOTOR COOLING                       Rotor having cooling passage
# 85   MOTOR COOLING                       Rotor having cooling passage
# 86   MOTOR COOLING              Rotor core having two cooling passage
# 87   MOTOR CONTROL     rotor control as PM or reluctance based on RPM
# 88   MOTOR COOLING                   Refrigernat guide Stator winding
# 89   MOTOR COOLING                 Stator Winding cooling arrangement
# 90   MOTOR COOLING                             Coolant guide on rotor
# 91   MOTOR COOLING  Heating coolant by immersing winding heat tran...
# 92    ROTOR MAGNET              Annular ring for holding rotor magnet
# 93          STATOR                     Tooths having different length
# 94   MOTOR CONTROL  Atmospheric pressure detection | Voltage excee...
#
#                                        Impact/Benefit AC/DC Motor  Phase  ...  \
# 10                                            Compact         NaN  Three  ...
# 11                                   Improved Cooling         NaN    NaN  ...
# 12                               Reduced Ground fault         NaN    NaN  ...
# 13  Suppressing demagnetization due to temperature...    AC OR DC  Three  ...
# 14                                   Improved Cooling         NaN  Three  ...
# 15                                                NVH         NaN    NaN  ...
# 16                                                NVH         NaN    NaN  ...
# 17                       Improved Structural Strength         NaN    NaN  ...
# 18                                  Passenger Comfort         NaN    NaN  ...
# 19  Improving the detection accuracy | Degree of d...          AC  Three  ...
# 20                                Improved efficiency         NaN    NaN  ...
# 70                                   Improved Cooling         NaN    NaN  ...
# 71                                Reduced Copper loss         NaN  Three  ...
# 72      Simplified Construction | Improved Efficiency         NaN  Three  ...
# 73                                   Improved Cooling         NaN  Three  ...
# 74                                   Improved Cooling         NaN  Three  ...
# 75         Improved Cooling | Simplified Construction          DC  Three  ...
# 76                                   Improved Cooling         NaN    NaN  ...
# 77                       Improved trapping efficiency         NaN    NaN  ...
# 78                                   Improved Cooling         NaN    NaN  ...
# 79                                   Improved Cooling         NaN    NaN  ...
# 80                                   Improved Cooling          AC  Three  ...
# 81                            Simplified Construction         NaN    NaN  ...
# 82  Reduced flux leakage | Improved torque charact...         NaN    NaN  ...
# 83                 Reduced interference with the coil         NaN    NaN  ...
# 84                                   Improved Cooling         NaN    NaN  ...
# 85                                   Improved Cooling         NaN    NaN  ...
# 86                                   Improved Cooling         NaN    NaN  ...
# 87         Improved Reliability | Improved Efficiency         NaN  Three  ...
# 88                                   Improved Cooling         NaN    NaN  ...
# 89                                   Improved Cooling         NaN    NaN  ...
# 90                                   Improved cooling         NaN    NaN  ...
# 91                            Simplified Construction         NaN  Three  ...
# 92                     Improved torque characterstics         NaN  Three  ...
# 93                     Improved torque characterstics         NaN    NaN  ...
# 94                                    Improved Safety          AC  Three  ...
#
#    Motor Position Family legal status Geography Count Cit Count Claim Count  \
# 10        Central             GRANTED               2         5           1
# 11        Central             GRANTED               2         8           1
# 12        Central             PENDING               2         1           2
# 13            NaN             PENDING               1         2           1
# 14            NaN             PENDING               1         1           1
# 15            NaN             REVOKED               1         1           1
# 16        Central             PENDING               1         2           1
# 17            NaN             PENDING               3         9           1
# 18            NaN             PENDING               3        11           2
# 19            NaN             GRANTED               3         8           2
# 20            NaN             GRANTED               3        17           1
# 70        Central             PENDING               2        12           1
# 71        Central             PENDING               1         8           1
# 72            NaN             GRANTED               2        11           1
# 73            NaN             PENDING               1         1           1
# 74        Central             PENDING               2        15           1
# 75        Central             GRANTED               2         1           1
# 76            NaN             REVOKED               2         5           1
# 77            NaN             GRANTED               2         2           1
# 78            NaN             GRANTED               2         2           1
# 79            NaN             GRANTED               2         1           1
# 80            NaN             GRANTED               2         5           2
# 81            NaN             GRANTED               2         1           2
# 82            NaN             PENDING               2         8           4
# 83            NaN             PENDING               2         6           1
# 84            NaN             GRANTED               2         9           1
# 85            NaN             GRANTED               2         1           1
# 86            NaN             PENDING               2         1           1
# 87            NaN             PENDING               1         2           1
# 88            NaN             GRANTED               2         1           1
# 89            NaN             GRANTED               2         1           1
# 90            NaN             GRANTED               1         1           1
# 91       In-wheel             GRANTED               1         1           1
# 92            NaN             PENDING               2         1           1
# 93            NaN             PENDING               3        10           1
# 94            NaN             GRANTED               3         9           1
#
#    Priority Country Overall Rating  \
# 10               JP           2.90
# 11               JP           2.90
# 12               JP           2.45
# 13               JP           2.85
# 14               JP           2.65
# 15               JP           2.75
# 16               JP           3.05
# 17               JP           2.55
# 18               JP           2.60
# 19               JP           3.20
# 20               JP           3.05
# 70               JP           2.70
# 71               JP           2.05
# 72               JP           3.05
# 73               JP           2.45
# 74               JP           2.70
# 75               JP           2.90
# 76               JP           2.25
# 77               JP           2.70
# 78               JP           2.70
# 79               JP           2.70
# 80               JP           2.80
# 81               JP           2.40
# 82               JP           3.05
# 83               JP           2.15
# 84               JP           2.70
# 85               JP           2.70
# 86               JP           2.55
# 87               JP           2.65
# 88               JP           2.70
# 89               JP           2.70
# 90               JP           2.60
# 91               JP           2.20
# 92               JP           2.55
# 93               JP           2.55
# 94               JP           2.50
#
#                                             Inventors Earliest priority date  \
# 10                                   KUBOTA YOSHINAGA             2017-11-08
# 11                                       ANDRII PYDIN             2017-12-22
# 12                                       BEPPU MASARU             2018-03-01
# 13                                       AKAI KENICHI             2019-12-06
# 14                                      YOKOTA HIROKI             2020-01-24
# 15                                      TORIGOE SEIYA             2020-03-16
# 16                                    KAMATA MASAHIRO             2020-03-24
# 17           ITO YUTA ([JP])\nYOSHIZAWA TAKUYA ([JP])             2017-12-19
# 18                               FUKUI KENTARO ([JP])             2018-02-08
# 19  TANAKA YOSUKE ([JP])\nARIMURA YUTAKA ([JP])\nH...             2018-03-22
# 20           KUBOTA YOSHIHISA ([JP])\nITO YUTA ([JP])             2018-07-30
# 70                                    SAKURADA MANABU             2017-11-27
# 71                                   KUBOTA YOSHINAGA             2017-12-12
# 72                                      SEKI YOSHIAKI             2017-12-15
# 73                                    KAMATA MASAHIRO             2018-01-25
# 74                  YOSHIIZUMI YUSUKE\nFUJITA MUNEAKI             2018-03-01
# 75                                   IMAMURA TAKEHIRO             2018-03-01
# 76                  TAKAHASHI TADANOBU\nWAKUI TAKASHI             2018-03-08
# 77                                     KAJIKAWA KAORU             2018-03-13
# 78                     Satoshi Ninomiya\nENDO RINTARO             2018-03-14
# 79                                       MIURA MASAYA             2018-03-16
# 80                                     KAJIKAWA KAORU             2018-03-19
# 81                                        KATO Shinji             2018-03-19
# 82           OHIRA KENGO\nâ**² Hama â**¼ Takeshi Mura             2018-03-20
# 83                                     OCHIAI, Yusuke             2018-03-20
# 84                                     TAKESHIMA TORU             2018-06-13
# 85                        NISHII FUMIYA\nIKI Tomotaka             2018-07-13
# 86                        KOGA YUJI\nKONISHI YOSHIAKI             2018-07-26
# 87                                      TORIGOE SEIYA             2019-01-09
# 88                                       ANDRII PYDIN             2019-01-22
# 89                                       ANDRII PYDIN             2019-01-22
# 90                    OKAJI TOMOYA\nSADAKIYO MASAYUKI             2019-01-23
# 91                                      PYDIN, Andrii             2019-06-14
# 92                 KUBOTA YOSHINAGA\nMATSUMOTO TEPPEI             2020-01-21
# 93                            KUBOTA YOSHIHISA ([JP])             2018-02-22
# 94       AZUSAWA KEISUKE ([JP])\nINOUE MASASHI ([JP])             2018-07-24
#
#     Application dates
# 10         2017-11-08
# 11         2017-12-22
# 12         2018-03-01
# 13         2019-12-06
# 14         2020-01-24
# 15         2020-03-16
# 16         2020-03-24
# 17         2018-12-18
# 18         2019-01-30
# 19         2019-03-21
# 20         2019-07-25
# 70         2017-11-27
# 71         2017-12-12
# 72         2017-12-15
# 73         2018-01-25
# 74         2018-03-01
# 75         2018-03-01
# 76         2018-03-08
# 77         2018-03-13
# 78         2018-03-14
# 79         2018-03-16
# 80         2018-03-19
# 81         2018-03-19
# 82         2018-03-20
# 83         2018-03-20
# 84         2018-06-13
# 85         2018-07-13
# 86         2018-07-26
# 87         2019-01-09
# 88         2019-01-22
# 89         2019-01-22
# 90         2019-01-23
# 91         2019-06-14
# 92         2020-05-20
# 93         2019-02-20
# 94         2019-07-23
#
# [36 rows x 27 columns]

# %%
x=df['Current assignees']

for i in range(len(df)):
    c=0
    for i in x:
        if i=='HONDA MOTOR':
            print(i)
            #c=c+1
print(c)
# Out:
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# HONDA MOTOR
# 0

# %%
df['Current assignees'].value_counts()
# Out:
# HONDA MOTOR              36
# HITACHI                  10
# FORD                     10
# DAIMLER                   9
# BYD                       8
# HYUNDAI|KIA               6
# DANA                      4
# TOYOTA                    2
# FAW                       2
# NIDEC                     2
# CONTINENTAL               2
# GM                        1
# BORGWARNER                1
# DENSO  |TOYOTA            1
# VOLKSWAGEN                1
# NISSAN                    1
# HONDA MOTOR  |HITACHI     1
# VITESCO                   1
# HYUNDAI                   1
# RENAULT  |NISSAN          1
# Name: Current assignees, dtype: int64

# %%
c=0
for i in range (len(df)):
    if df['Current assignees']=='HONDA MOTOR':
        c+=1
c
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-486b4232201f> in <module>
#       1 c=0
#       2 for i in range (len(df)):
# ----> 3     if df['Current assignees']=='HONDA MOTOR':
#       4         c+=1
#       5 c
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df.drop(df.filter(regex="Unname"),axis=1, inplace=True)

# %%
df.rename(columns = {'Phase ':'Phase'}, inplace = True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
filter = (df['Current assignees'] == 'HONDA MOTOR').any()
sub_df = df.loc[: , filter]
print(sub_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     722             try:
# --> 723                 self._validate_key(k, i)
#     724             except ValueError as err:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1374         else:
# -> 1375             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#    1376
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-5def72ba62b9> in <module>
#       1 filter = (df['Current assignees'] == 'HONDA MOTOR').any()
# ----> 2 sub_df = df.iloc[: , filter]
#       3 print(sub_df)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1448     def _getitem_tuple(self, tup: Tuple):
#    1449
# -> 1450         self._has_valid_tuple(tup)
#    1451         with suppress(IndexingError):
#    1452             return self._getitem_lowerdim(tup)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     723                 self._validate_key(k, i)
#     724             except ValueError as err:
# --> 725                 raise ValueError(
#     726                     "Location based indexing can only have "
#     727                     f"[{self._valid_types}] types"
#
# ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Fam. No.                100 non-null    int64
#  1   Publication no          100 non-null    object
#  2   Current assignees       100 non-null    object
#  3   Player Type             100 non-null    object
#  4   XX Rating               100 non-null    int64
#  5   Sub-component           100 non-null    object
#  6   Uniqueness              100 non-null    object
#  7   Impact/Benefit          100 non-null    object
#  8   AC/DC Motor             23 non-null     object
#  9   Phase                   31 non-null     object
#  10  MOTOR Type              19 non-null     object
#  11  Winding config          1 non-null      object
#  12  Hairpin                 8 non-null      object
#  13  Flux                    2 non-null      object
#  14  Cooling Passage         15 non-null     object
#  15  Coolant guide           4 non-null      object
#  16  Cooling Type            48 non-null     object
#  17  Motor Position          17 non-null     object
#  18  Family legal status     100 non-null    object
#  19  Geography Count         100 non-null    int64
#  20  Cit Count               100 non-null    int64
#  21  Claim Count             100 non-null    int64
#  22  Priority Country        100 non-null    object
#  23  Overall Rating          100 non-null    float64
#  24  Inventors               100 non-null    object
#  25  Earliest priority date  100 non-null    datetime64[ns]
#  26  Application dates       100 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(5), object(19)
# memory usage: 21.2+ KB

# %%
df.isnull().sum()
# Out:
# Fam. No.                   0
# Publication no             0
# Current assignees          0
# Player Type                0
# XX Rating                  0
# Sub-component              0
# Uniqueness                 0
# Impact/Benefit             0
# AC/DC Motor               77
# Phase                     69
# MOTOR Type                81
# Winding config            99
# Hairpin                   92
# Flux                      98
# Cooling Passage           85
# Coolant guide             96
# Cooling Type              52
# Motor Position            83
# Family legal status        0
# Geography Count            0
# Cit Count                  0
# Claim Count                0
# Priority Country           0
# Overall Rating             0
# Inventors                  0
# Earliest priority date     0
# Application dates          0
# dtype: int64

# %%
df.shape
# Out:
# (100, 27)

# %%
df.dtypes
# Out:
# Fam. No.                           int64
# Publication no                    object
# Current assignees                 object
# Player Type                       object
# XX Rating                          int64
# Sub-component                     object
# Uniqueness                        object
# Impact/Benefit                    object
# AC/DC Motor                       object
# Phase                             object
# MOTOR Type                        object
# Winding config                    object
# Hairpin                           object
# Flux                              object
# Cooling Passage                   object
# Coolant guide                     object
# Cooling Type                      object
# Motor Position                    object
# Family legal status               object
# Geography Count                    int64
# Cit Count                          int64
# Claim Count                        int64
# Priority Country                  object
# Overall Rating                   float64
# Inventors                         object
# Earliest priority date    datetime64[ns]
# Application dates         datetime64[ns]
# dtype: object

# %%
df.describe()
# Out:
#          Fam. No.   XX Rating  Geography Count   Cit Count  Claim Count  \
# count  100.000000  100.000000       100.000000  100.000000   100.000000
# mean    50.500000    3.340000         2.270000    5.390000     1.610000
# std     29.011492    0.535978         1.117853    5.086911     0.851558
# min      1.000000    3.000000         1.000000    0.000000     1.000000
# 25%     25.750000    3.000000         1.000000    1.000000     1.000000
# 50%     50.500000    3.000000         2.000000    5.000000     1.000000
# 75%     75.250000    4.000000         3.000000    8.000000     2.000000
# max    100.000000    5.000000         6.000000   24.000000     4.000000
#
#        Overall Rating
# count      100.000000
# mean         2.803500
# std          0.326541
# min          2.050000
# 25%          2.600000
# 50%          2.750000
# 75%          3.050000
# max          3.600000

# %%
df.columns
# Out:
# Index(['Fam. No.', 'Publication no', 'Current assignees', 'Player Type',
#        'XX Rating', 'Sub-component', 'Uniqueness', 'Impact/Benefit',
#        'AC/DC Motor', 'Phase', 'MOTOR Type', 'Winding config', 'Hairpin',
#        'Flux', 'Cooling Passage', 'Coolant guide', 'Cooling Type',
#        'Motor Position', 'Family legal status', 'Geography Count', 'Cit Count',
#        'Claim Count', 'Priority Country', 'Overall Rating', 'Inventors',
#        'Earliest priority date', 'Application dates'],
#       dtype='object')

# %%
df.groupby(['Priority Country']).sum().plot(kind='pie', y='Overall Rating', autopct='%1.0f%%')

import matplotlib.pyplot as plt
fig = plt.gcf()
fig.set_size_inches(10, 8)
fig.savefig('test2png.png', dpi=100)

# %%
'Current assignees'
'Sub-component'

# %%
import seaborn as sns

sns.heatmap(df['Sub-component'],linewidths=.5,cmap="YlGnBu")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-aaab33b465cf> in <module>
#       1 import seaborn as sns
#       2
# ----> 3 sns.heatmap(df['Sub-component'],linewidths=.5,cmap="YlGnBu")
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     533     """
#     534     # Initialize the plotter object
# --> 535     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     536                           annot_kws, cbar, cbar_kws, xticklabels,
#     537                           yticklabels, mask)
#
# ~\anaconda3\lib\site-packages\seaborn\matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     105         mask = _matrix_mask(data, mask)
#     106
# --> 107         plot_data = np.ma.masked_where(np.asarray(mask), plot_data)
#     108
#     109         # Get good names for the rows and columns
#
# ~\anaconda3\lib\site-packages\numpy\ma\core.py in masked_where(condition, a, copy)
#    1933     (cshape, ashape) = (cond.shape, a.shape)
#    1934     if cshape and cshape != ashape:
# -> 1935         raise IndexError("Inconsistent shape between the condition and the input"
#    1936                          " (got %s and %s)" % (cshape, ashape))
#    1937     if hasattr(a, '_mask'):
#
# IndexError: Inconsistent shape between the condition and the input (got (100, 1) and (100,))
