# %%
from tkinter import * 
from tkinter.ttk import *
    
root = Tk()
root.title("First_Program")
  

label = Label(root, text ="Hello World !").pack()
  
 
root.mainloop()

# %%
from tkinter import *
  
  
root = Tk()                           
  
# frame inside root window
frame = Frame(root)                  
  
# geometry method
frame.pack()                          
  
# button inside frame which is 
# inside root
button = Button(frame, text ='Geek')  
button.pack()                         
  
# Tkinter event loop
root.mainloop()

# %%
from tkinter import *   
 
# create a tkinter window
root = Tk()             
 
# Open window having dimension 100x100
root.geometry('100x100')
 
# Create a Button
btn = Button(root, text = 'Click me !', bd = '5',
                          command = root.destroy)
 
# Set the position of button on the top of window.  
btn.pack(side = 'top')   
 
root.mainloop()

# %%
from tkinter import *

def donothing():
    
    filewin = Toplevel(root)
    button = Button(filewin, text="Do nothing button")
    button.pack()
   
root = Tk()
menubar = Menu(root)
filemenu = Menu(menubar, tearoff=0)
filemenu.add_command(label="New", command=donothing)
filemenu.add_command(label="Open", command=donothing)
filemenu.add_command(label="Save", command=donothing)
filemenu.add_command(label="Save as...", command=donothing)
filemenu.add_command(label="Close", command=donothing)

filemenu.add_separator()

filemenu.add_command(label="Exit", command=root.quit)
menubar.add_cascade(label="File", menu=filemenu)
editmenu = Menu(menubar, tearoff=0)
editmenu.add_command(label="Undo", command=donothing)

editmenu.add_separator()

editmenu.add_command(label="Cut", command=donothing)
editmenu.add_command(label="Copy", command=donothing)
editmenu.add_command(label="Paste", command=donothing)
editmenu.add_command(label="Delete", command=donothing)
editmenu.add_command(label="Select All", command=donothing)

menubar.add_cascade(label="Edit", menu=editmenu)
helpmenu = Menu(menubar, tearoff=0)
helpmenu.add_command(label="Help Index", command=donothing)
helpmenu.add_command(label="About...", command=donothing)
menubar.add_cascade(label="Help", menu=helpmenu)

root.config(menu=menubar)
root.mainloop()

# %%
from tkinter import Tk     # from tkinter import Tk for Python 3.x
from tkinter.filedialog import askopenfilename

Tk().withdraw() # we don't want a full GUI, so keep the root window from appearing
filename = askopenfilename() # show an "Open" dialog box and return the path to the selected file
print(filename)
# Out:
# C:/Users/HP/Downloads/WA_Fn-UseC_-Telco-Customer-Churn.csv

# %%
from tkinter import * 
import pyttsx3
root = Tk()             
 

root.geometry('500x300')
root.configure(bg="white")
def talk():
    

    engine = pyttsx3.init()
    voices=engine.getProperty('voices')
    engine.setProperty('voice',voices[1].id)
    engine.say(entry.get())
    engine.runAndWait()
    entry.delete(0,END)

    
    
L = Label(root, text="Enter text",width='18',bg='black',bd='5',fg="white",height='1')
L.pack( side = LEFT)

    
    
    
    

entry=Entry(root, bd ='6',bg='pink',fg='black',width='45')
entry.pack(side = RIGHT)


btn=Button(root,text='Speak',command=talk,activebackground="red",activeforeground="white",bd='8',bg='yellow',height='2',width='50')
btn.pack(side=BOTTOM)




root.mainloop()

# %%
from tkinter import *
from PIL import ImageTk,Image
from tkinter import filedialog as fd
import speech_recognition as sr
import pyttsx3
from tkinter.messagebox import showinfo
from tkinter import ttk
import tkinter as tk
from PIL import ImageTk, Image

#root = tk.Tk()
root=Tk()
root.geometry('800x700')
#root.configure(bg="white")
root.resizable(False, False)
root['bg'] = '#49A'
#root.config(bg='#116562')




# from PIL import ImageTk, Image
# img = ImageTk.PhotoImage(Image.open("apple-music-note.jpg"))  
# l=Label(image=img)
# l.pack()

# bg = PhotoImage(file = "apple-music-note.png")
# label1 = Label( root, image = bg)
# label1.place(x = 0, y = 0)

l0 = Label(root, text="Speech to Text",width='25',bg='light green',bd='5',fg="black",height='2',font = "Verdana 10 bold").pack()
#l1 = Label(root, text="Choose a file").pack()


def select_file():
    filetypes = (('wav files', '*.wav'),('All files', '*.*'))

    select_file.filename = fd.askopenfilename(title='Open a file',initialdir='/',filetypes=filetypes)

    showinfo(title='Selected File',message=select_file.filename)


# open button
open_button = ttk.Button(root,text='Open a File',command=select_file,width='28')

open_button.pack(expand=True)

#root.filename = filedialog.askopenfilename(title='Select A File',filetypes=(('wav files', '*.wav'),('all files','*.*')))

def transcript():
    filename = select_file.filename
    r = sr.Recognizer()
    with sr.AudioFile(filename) as source:    
        audio_data = r.record(source)
        transcript.text = r.recognize_google(audio_data)
        my_text.insert(END,transcript.text)
        
def talk():
    

    engine = pyttsx3.init()
    voices=engine.getProperty('voices')
    engine.setProperty('voice',voices[1].id)
    engine.say(transcript.text)
    engine.runAndWait()
    
#l2 = Label(root, text=root.filename).pack()


btn1=Button(root,text='Transcript',command=transcript,activebackground="red",activeforeground="white",bd='5',bg='yellow',height='2',width='28',fg='Black',font=('Times', 11)).pack()
#print(btn1)
my_text = Text(root,background='floral white',font=('Times', 12))
# text.insert( text)
my_text.pack()


l3 = Label(root, text="Text to Speech",width='25',bg='light green',bd='5',fg="black",height='2',font = "Verdana 10 bold").pack()
btn2=Button(root,text='Speak',command=talk,activebackground="red",activeforeground="white",bd='5',bg='yellow',height='2',width='25',font=('Times', 11)).pack()
print(btn2)



root.mainloop()
# Out:
# None

# %%
def fun1():
    fun1.var = 100
    print(var)

def fun2():
    print(fun1.var)

fun1()
fun2()

print(fun1.var)
# Out:
# PY_VAR1
# 100
# 100
