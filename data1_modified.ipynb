# %%
import pandas as pd

df=pd.read_csv('data1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        ID    Client  Tag Country Number  Strs  Type  \
# 0           0  2000918O  FLIBONBT    7     MAU    NaN   NaN   NaN
# 1           1  2000918O  FLIBONBT    8     MAU    NaN   NaN   NaN
# 2           2  2000918O  FLIBONBT   11     MAU    NaN   2.0  Test
# 3           3  2000918O  FLIBONBT   11     MAU    NaN   2.0  Test
# 4           4  2000918O  FLIBONBT   11     MAU    NaN   2.0  Test
#
#            Dety        Rest    Tent   Renew CdsRoute
# 0           NaN         NaN     NaN     NaN      NaN
# 1           NaN         NaN     NaN     NaN      NaN
# 2  4-Extra Dark  1NEH00029A  1669.0  9869.9     DSFF
# 3  4-Extra Dark  1NEH00029A  1669.0  9869.9     DFGH
# 4  4-Extra Dark  1NEH00029A  1669.0  9869.9   FSTPAD

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# ID             0
# Client         0
# Tag            0
# Country       11
# Number        39
# Strs           7
# Type           7
# Dety           7
# Rest           7
# Tent           7
# Renew          7
# CdsRoute       7
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# ID             object
# Client         object
# Tag             int64
# Country        object
# Number         object
# Strs          float64
# Type           object
# Dety           object
# Rest           object
# Tent          float64
# Renew         float64
# CdsRoute       object
# dtype: object

# %% [markdown]
# #### 1. Replace null value with 'Blank' in String column and '0' in integer column.

# %%
df.update(df[['Country','Number','Type','Dety','Rest','CdsRoute']].fillna('Blank'))
df.update(df[['Strs','Tent','Renew']].fillna(0))
df.head(50)
# Out:
#     Unnamed: 0        ID    Client  Tag Country            Number  Strs  \
# 0            0  2000918O  FLIBONBT    7     MAU             Blank   0.0
# 1            1  2000918O  FLIBONBT    8     MAU             Blank   0.0
# 2            2  2000918O  FLIBONBT   11     MAU             Blank   2.0
# 3            3  2000918O  FLIBONBT   11     MAU             Blank   2.0
# 4            4  2000918O  FLIBONBT   11     MAU             Blank   2.0
# 5            5  2000918O  FLIBONBT   11     MAU             Blank   2.0
# 6            6  2000918O  FLIBONBT   11     MAU             Blank   2.0
# 7            7  2000918O  FLIBONBT   11     MAU             Blank   2.0
# 8            8  2000918O  FLIBONBT   11     MAU             Blank   2.0
# 9            9  2000918O  FLIBONBT   11     MAU             Blank   2.0
# 10          10  2000918O  FLIBONBT   11     MAU             Blank   2.0
# 11          11  2000918O  FLIBONBT   11     MAU             Blank   2.0
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# ID            0
# Client        0
# Tag           0
# Country       0
# Number        0
# Strs          0
# Type          0
# Dety          0
# Rest          0
# Tent          0
# Renew         0
# CdsRoute      0
# dtype: int64

# %% [markdown]
# #### 2. Drop duplicate entry

# %%
duplicate = df[df.duplicated()]
  
#print("Duplicate Rows :")
  
# Print the resultant Dataframe
print(duplicate)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, Client, Tag, Country, Number, Strs, Type, Dety, Rest, Tent, Renew, CdsRoute]
# Index: []

# %%
df.duplicated().sum()
# Out:
# 0

# %%
x=df[df.duplicated()]
x
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, Client, Tag, Country, Number, Strs, Type, Dety, Rest, Tent, Renew, CdsRoute]
# Index: []

# %% [markdown]
# #### 3. Sort the data bye Tag

# %%
df.sort_values(by=['Tag'], ascending=True)
# Out:
#     Unnamed: 0       ID   Client  Tag Country            Number  Strs  \
# 38          38   343633  DEMPPPP    1     MAU  EXC-CF1802661/01   2.0
# 40          40   343633  DEMPPPP    1     MAU  EXC-CF1802661/01   2.0
# 41          41   343633  DEMPPPP    1     MAU  EXC-CF1802661/01   2.0
# 42          42   343633  DEMPPPP    1     MAU  EXC-CF1802661/01   2.0
# 43          43   343633  DEMPPPP    1     MAU  EXC-CF1802661/01   2.0
# ..         ...      ...      ...  ...     ...               ...   ...
# 37          37  2433563     DEMP   11     MAU             Blank   2.0
# 36          36  2433563     DEMP   11     MAU             Blank   2.0
# 35          35  2433563     DEMP   11     MAU             Blank   2.0
# 19          19   243673       sd   11   Blank             Blank   2.0
# 33          33  2433563     DEMP   11     MAU             Blank   2.0
#
#                 Type          Dety        Rest    Tent    Renew  CdsRoute
# ...

# %% [markdown]
# #### 4. Change datatype to string of column 'Tag'

# %%
df['Tag'] = df['Tag'].map(str)

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# ID             object
# Client         object
# Tag            object
# Country        object
# Number         object
# Strs          float64
# Type           object
# Dety           object
# Rest           object
# Tent          float64
# Renew         float64
# CdsRoute       object
# dtype: object

# %%
# sorted_df = sorted_df.astype({"Tag": str})
# sorted_df.dtypes

# %%
df.to_csv('data1_modified.csv')
