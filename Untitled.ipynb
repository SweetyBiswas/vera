# %%
import pandas as pd

# %%
df = pd.read_excel('Sample_Data_1.xlsx')

# %%
df.head()
# Out:
#    Fam. No. Publication no Current assignees Player Type  XX Rating  \
# 0         1     Reference9               BYD         OEM          5
# 1         2    Reference10               BYD         OEM          5
# 2         3   Reference330             NIDEC     Suplier          5
# 3         4    Reference12               BYD         OEM          4
# 4         5    Reference34           DAIMLER         OEM          4
#
#    Sub-component                                   Uniqueness  \
# 0  MOTOR COOLING  Oil-cooled cooling system | Spraying device
# 1   MOTOR CASING                  Water-cooled cooling device
# 2        Winding                             Hairpin windings
# 3   MOTOR CASING                             Silencing spaces
# 4         STATOR                             Cooling channels
#
#                        Impact/Benefit AC/DC Motor Phase   ...  \
# 0          Improved cooling | Compact         NaN    NaN  ...
# ...

# %%
df.sample()
# Out:
#     Fam. No. Publication no Current assignees Player Type  XX Rating  \
# 65        66    Reference82           HITACHI     Suplier          3
#
#     Sub-component        Uniqueness                 Impact/Benefit  \
# 65  MOTOR WINDING  Hairpin windings  Compact | Improved efficiency
#
#    AC/DC Motor Phase   ... Earliest priority date Application dates  \
# 65         NaN  Three  ...             2018-05-25        2019-05-22
#
#    Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32  \
# 65         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 33  Unnamed: 34
# 65         NaN          NaN
#
# [1 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Fam. No.                100 non-null    int64
#  1   Publication no          100 non-null    object
#  2   Current assignees       100 non-null    object
#  3   Player Type             100 non-null    object
#  4   XX Rating               100 non-null    int64
#  5   Sub-component           100 non-null    object
#  6   Uniqueness              100 non-null    object
#  7   Impact/Benefit          100 non-null    object
#  8   AC/DC Motor             23 non-null     object
#  9   Phase                   31 non-null     object
#  10  MOTOR Type              19 non-null     object
#  11  Winding config          1 non-null      object
#  12  Hairpin                 8 non-null      object
#  13  Flux                    2 non-null      object
# ...

# %%
df.drop(df.filter(regex="Unname"),axis=1, inplace=True)

# %%
df.head()
# Out:
#    Fam. No. Publication no Current assignees Player Type  XX Rating  \
# 0         1     Reference9               BYD         OEM          5
# 1         2    Reference10               BYD         OEM          5
# 2         3   Reference330             NIDEC     Suplier          5
# 3         4    Reference12               BYD         OEM          4
# 4         5    Reference34           DAIMLER         OEM          4
#
#    Sub-component                                   Uniqueness  \
# 0  MOTOR COOLING  Oil-cooled cooling system | Spraying device
# 1   MOTOR CASING                  Water-cooled cooling device
# 2        Winding                             Hairpin windings
# 3   MOTOR CASING                             Silencing spaces
# 4         STATOR                             Cooling channels
#
#                        Impact/Benefit AC/DC Motor Phase   ... Motor Position  \
# 0          Improved cooling | Compact         NaN    NaN  ...            NaN
# ...

# %%
df.rename(columns = {'Phase ':'Phase'}, inplace = True)

# %%
df.head(3)
# Out:
#    Fam. No. Publication no Current assignees Player Type  XX Rating  \
# 0         1     Reference9               BYD         OEM          5
# 1         2    Reference10               BYD         OEM          5
# 2         3   Reference330             NIDEC     Suplier          5
#
#    Sub-component                                   Uniqueness  \
# 0  MOTOR COOLING  Oil-cooled cooling system | Spraying device
# 1   MOTOR CASING                  Water-cooled cooling device
# 2        Winding                             Hairpin windings
#
#                Impact/Benefit AC/DC Motor Phase  ... Motor Position  \
# 0  Improved cooling | Compact         NaN   NaN  ...            NaN
# 1                     Compact         NaN   NaN  ...            NaN
# 2            Improved Cooling          AC   NaN  ...            NaN
#
#   Family legal status Geography Count Cit Count Claim Count Priority Country  \
# 0             GRANTED               1         0           1               CN
# ...

# %%
df.isnull().sum()
# Out:
# Fam. No.                   0
# Publication no             0
# Current assignees          0
# Player Type                0
# XX Rating                  0
# Sub-component              0
# Uniqueness                 0
# Impact/Benefit             0
# AC/DC Motor               77
# Phase                     69
# MOTOR Type                81
# Winding config            99
# Hairpin                   92
# Flux                      98
# Cooling Passage           85
# Coolant guide             96
# Cooling Type              52
# Motor Position            83
# Family legal status        0
# Geography Count            0
# Cit Count                  0
# Claim Count                0
# Priority Country           0
# Overall Rating             0
# Inventors                  0
# Earliest priority date     0
# Application dates          0
# dtype: int64

# %%
df.shape
# Out:
# (100, 27)

# %%
df.dtypes
# Out:
# Fam. No.                           int64
# Publication no                    object
# Current assignees                 object
# Player Type                       object
# XX Rating                          int64
# Sub-component                     object
# Uniqueness                        object
# Impact/Benefit                    object
# AC/DC Motor                       object
# Phase                             object
# MOTOR Type                        object
# Winding config                    object
# Hairpin                           object
# Flux                              object
# Cooling Passage                   object
# Coolant guide                     object
# Cooling Type                      object
# Motor Position                    object
# Family legal status               object
# Geography Count                    int64
# Cit Count                          int64
# Claim Count                        int64
# Priority Country                  object
# ...

# %%
df.describe()
# Out:
#          Fam. No.   XX Rating  Geography Count   Cit Count  Claim Count  \
# count  100.000000  100.000000       100.000000  100.000000   100.000000
# mean    50.500000    3.340000         2.270000    5.390000     1.610000
# std     29.011492    0.535978         1.117853    5.086911     0.851558
# min      1.000000    3.000000         1.000000    0.000000     1.000000
# 25%     25.750000    3.000000         1.000000    1.000000     1.000000
# 50%     50.500000    3.000000         2.000000    5.000000     1.000000
# 75%     75.250000    4.000000         3.000000    8.000000     2.000000
# max    100.000000    5.000000         6.000000   24.000000     4.000000
#
#        Overall Rating
# count      100.000000
# mean         2.803500
# std          0.326541
# min          2.050000
# 25%          2.600000
# 50%          2.750000
# 75%          3.050000
# max          3.600000

# %%
df.columns
# Out:
# Index(['Fam. No.', 'Publication no', 'Current assignees', 'Player Type',
#        'XX Rating', 'Sub-component', 'Uniqueness', 'Impact/Benefit',
#        'AC/DC Motor', 'Phase', 'MOTOR Type', 'Winding config', 'Hairpin',
#        'Flux', 'Cooling Passage', 'Coolant guide', 'Cooling Type',
#        'Motor Position', 'Family legal status', 'Geography Count', 'Cit Count',
#        'Claim Count', 'Priority Country', 'Overall Rating', 'Inventors',
#        'Earliest priority date', 'Application dates'],
#       dtype='object')

# %%
df[['Priority Country','Overall Rating']]
# Out:
#    Priority Country  Overall Rating
# 0                CN            3.20
# 1                CN            2.85
# 2                FR            3.20
# 3                CN            3.05
# 4                DE            2.70
# ..              ...             ...
# 95               JP            2.65
# 96               KR            3.35
# 97               KR            3.20
# 98               KR            2.80
# 99               KR            2.90
#
# [100 rows x 2 columns]

# %%
df.groupby(['Priority Country']).sum().plot(kind='pie', y='Overall Rating', autopct='%1.0f%%')

import matplotlib.pyplot as plt
fig = plt.gcf()
fig.set_size_inches(10, 8)
fig.savefig('test2png.png', dpi=100)

# %%
import seaborn as sns
sns.barplot(x = 'Priority Country', y = 'Overall Rating', data = df,
            palette = 'PuRd',ci=None
           )
# Out:
# <AxesSubplot:xlabel='Priority Country', ylabel='Overall Rating'>

# %%
plt.bar(df['Priority Country'],df['Overall Rating'])
# Out:
# <BarContainer object of 100 artists>

# %%
import seaborn as sns
plt.figure(figsize=(12,7))
sns.countplot(data=df, y='Priority Country',alpha=.6,color='blue')
#plt.title('Company by sub-component',fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('')
plt.ylabel('');

# %%
df['Player Type'].value_counts()
# Out:
# OEM               80
# Suplier           18
# OEM + Supplier     2
# Name: Player Type, dtype: int64

# %%
df.head(1)
# Out:
#    Fam. No. Publication no Current assignees Player Type  XX Rating  \
# 0         1     Reference9               BYD         OEM          5
#
#    Sub-component                                   Uniqueness  \
# 0  MOTOR COOLING  Oil-cooled cooling system | Spraying device
#
#                Impact/Benefit AC/DC Motor Phase  ... Motor Position  \
# 0  Improved cooling | Compact         NaN   NaN  ...            NaN
#
#   Family legal status Geography Count Cit Count Claim Count Priority Country  \
# 0             GRANTED               1         0           1               CN
#
#   Overall Rating                                   Inventors  \
# 0            3.2  WANG JIANXIN\nZOU XIAOSONG\nFANG ZHAOXIANG
#
#   Earliest priority date  Application dates
# 0             2019-04-15         2019-04-15
#
# [1 rows x 27 columns]

# %% [markdown]
# ### In 2019 if Current assignees is DAIMLER what was the claim count?

# %%
Application dates=2019,Current assignees=DAIMLER

# %%
x=df['Player Type']
l=[]
for i in range(len(df)):
    for i in x:
        if i=='OEM':
            l.append(df['Priority Country'])
        
print(l)
# Out:
# [0     CN
# 1     CN
# 2     FR
# 3     CN
# 4     DE
#       ..
# 95    JP
# 96    KR
# 97    KR
# 98    KR
# 99    KR
# Name: Priority Country, Length: 100, dtype: object, 0     CN
# 1     CN
# 2     FR
# 3     CN
# 4     DE
#       ..
# 95    JP
# 96    KR
# 97    KR
# 98    KR
# 99    KR
# Name: Priority Country, Length: 100, dtype: object, 0     CN
# 1     CN
# 2     FR
# 3     CN
# 4     DE
#       ..
# 95    JP
# 96    KR
# 97    KR
# 98    KR
# 99    KR
# Name: Priority Country, Length: 100, dtype: object, 0     CN
# 1     CN
# 2     FR
# 3     CN
# 4     DE
#       ..
# 95    JP
# 96    KR
# 97    KR
# 98    KR
# 99    KR
# Name: Priority Country, Length: 100, dtype: object, 0     CN
# 1     CN
# 2     FR
# 3     CN
# 4     DE
#       ..
# 95    JP
# 96    KR
# 97    KR
# 98    KR
# 99    KR
# Name: Priority Country, Length: 100, dtype: object, 0     CN
# 1     CN
# 2     FR
# 3     CN
# 4     DE
#       ..
# 95    JP
# 96    KR
# 97    KR
# 98    KR
# 99    KR
# ...

# %%
df['Player Type'].value_counts()
# Out:
# OEM               80
# Suplier           18
# OEM + Supplier     2
# Name: Player Type, dtype: int64

# %%
df.groupby('Player Type')
# Out:
#                 Fam. No.  Publication no  Current assignees  XX Rating  \
# Player Type
# OEM                   80              80                 80         80
# OEM + Supplier         2               2                  2          2
# Suplier               18              18                 18         18
#
#                 Sub-component  Uniqueness  Impact/Benefit  AC/DC Motor  Phase  \
# Player Type
# OEM                        80          80              80           14     25
# OEM + Supplier              2           2               2            1      1
# Suplier                    18          18              18            8      5
#
#                 MOTOR Type  ...  Motor Position  Family legal status  \
# Player Type                 ...
# OEM                     12  ...              13                   80
# OEM + Supplier           0  ...               0                    2
# Suplier                  7  ...               4                   18
#
# ...
