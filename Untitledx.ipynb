# %%
pip install jupyter_dashboards
# Out:
# Collecting jupyter_dashboards
#   Downloading jupyter_dashboards-0.7.0.tar.gz (2.9 MB)
# Requirement already satisfied: notebook>=4.0 in c:\users\hp\anaconda3\lib\site-packages (from jupyter_dashboards) (6.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_dashboards) (0.9.4)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_dashboards) (6.1.12)
# Requirement already satisfied: traitlets>=4.2.1 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_dashboards) (5.0.5)
# Requirement already satisfied: prometheus-client in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_dashboards) (0.10.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_dashboards) (6.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_dashboards) (20.0.0)
# Requirement already satisfied: argon2-cffi in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_dashboards) (20.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_dashboards) (1.5.0)
# Requirement already satisfied: ipython-genutils in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_dashboards) (0.2.0)
# Requirement already satisfied: nbconvert in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_dashboards) (6.0.7)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_dashboards) (4.7.1)
# Requirement already satisfied: nbformat in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_dashboards) (5.1.3)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_dashboards) (2.11.3)
# Requirement already satisfied: ipykernel in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.0->jupyter_dashboards) (5.3.4)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.0->jupyter_dashboards) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook>=4.0->jupyter_dashboards) (227)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client>=5.3.4->notebook>=4.0->jupyter_dashboards) (1.15.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\hp\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.0->jupyter_dashboards) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.0->jupyter_dashboards) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.0->jupyter_dashboards) (2.20)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->notebook>=4.0->jupyter_dashboards) (7.22.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (0.17.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (3.0.17)
# Requirement already satisfied: decorator in c:\users\hp\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (5.0.6)
# Requirement already satisfied: backcall in c:\users\hp\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (0.2.0)
# Requirement already satisfied: pygments in c:\users\hp\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (2.8.1)
# Requirement already satisfied: pickleshare in c:\users\hp\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\hp\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (52.0.0.post20210125)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (0.4.4)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\hp\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\hp\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook>=4.0->jupyter_dashboards) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->notebook>=4.0->jupyter_dashboards) (2.0.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (0.3)
# Requirement already satisfied: testpath in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (1.4.3)
# Requirement already satisfied: defusedxml in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (0.7.1)
# Requirement already satisfied: bleach in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (3.3.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (0.8.4)
# Requirement already satisfied: nest-asyncio in c:\users\hp\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.0->jupyter_dashboards) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\hp\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.0->jupyter_dashboards) (1.10)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\hp\anaconda3\lib\site-packages (from nbformat->notebook>=4.0->jupyter_dashboards) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.0->jupyter_dashboards) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.0->jupyter_dashboards) (20.3.0)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.0->jupyter_dashboards) (20.9)
# Requirement already satisfied: webencodings in c:\users\hp\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.0->jupyter_dashboards) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\hp\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.0->jupyter_dashboards) (2.4.7)
# Building wheels for collected packages: jupyter-dashboards
#   Building wheel for jupyter-dashboards (setup.py): started
#   Building wheel for jupyter-dashboards (setup.py): finished with status 'done'
#   Created wheel for jupyter-dashboards: filename=jupyter_dashboards-0.7.0-py3-none-any.whl size=3643485 sha256=42a5539858f178e524379dc0916a8223145ab3d592aae4ca0286521e3c76b3b8
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\56\2c\08\ad1c0d7487d9968e95ea9bf2168e6ac8fcf22d3ab6fe9f47cd
# Successfully built jupyter-dashboards
# Installing collected packages: jupyter-dashboards
# Successfully installed jupyter-dashboards-0.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyter-dash
# Out:
# Collecting jupyter-dash
#   Downloading jupyter_dash-0.4.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from jupyter-dash) (2.25.1)
# Requirement already satisfied: ipykernel in c:\users\hp\anaconda3\lib\site-packages (from jupyter-dash) (5.3.4)
# Requirement already satisfied: ipython in c:\users\hp\anaconda3\lib\site-packages (from jupyter-dash) (7.22.0)
# Collecting dash
#   Downloading dash-2.3.0-py3-none-any.whl (9.6 MB)
# Requirement already satisfied: flask in c:\users\hp\anaconda3\lib\site-packages (from jupyter-dash) (1.1.2)
# Collecting retrying
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Collecting ansi2html
#   Downloading ansi2html-1.7.0-py3-none-any.whl (15 kB)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting flask-compress
#   Downloading Flask_Compress-1.11-py3-none-any.whl (7.9 kB)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\hp\anaconda3\lib\site-packages (from dash->jupyter-dash) (5.3.1)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\hp\anaconda3\lib\site-packages (from flask->jupyter-dash) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\hp\anaconda3\lib\site-packages (from flask->jupyter-dash) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\hp\anaconda3\lib\site-packages (from flask->jupyter-dash) (1.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\hp\anaconda3\lib\site-packages (from flask->jupyter-dash) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hp\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter-dash) (2.0.1)
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->jupyter-dash) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hp\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->jupyter-dash) (8.0.1)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp38-cp38-win_amd64.whl (365 kB)
# Requirement already satisfied: tornado>=4.2 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (6.1)
# Requirement already satisfied: jupyter-client in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (6.1.12)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (5.0.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.17.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\hp\anaconda3\lib\site-packages (from ipython->jupyter-dash) (52.0.0.post20210125)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from ipython->jupyter-dash) (3.0.17)
# Requirement already satisfied: pygments in c:\users\hp\anaconda3\lib\site-packages (from ipython->jupyter-dash) (2.8.1)
# Requirement already satisfied: decorator in c:\users\hp\anaconda3\lib\site-packages (from ipython->jupyter-dash) (5.0.6)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\hp\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: backcall in c:\users\hp\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\hp\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\hp\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\hp\anaconda3\lib\site-packages (from traitlets>=4.1.0->ipykernel->jupyter-dash) (0.2.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter-dash) (4.7.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter-dash) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter-dash) (20.0.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter-dash) (227)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests->jupyter-dash) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\hp\anaconda3\lib\site-packages (from requests->jupyter-dash) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests->jupyter-dash) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests->jupyter-dash) (1.26.4)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=0ec3bef244ad15733ef3be6f9add13cf43ffb402f3124aa82d34c7615270d7e1
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# Installing collected packages: brotli, flask-compress, dash-table, dash-html-components, dash-core-components, retrying, dash, ansi2html, jupyter-dash
# Successfully installed ansi2html-1.7.0 brotli-1.0.9 dash-2.3.0 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 flask-compress-1.11 jupyter-dash-0.4.1 retrying-1.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
# Load Data
df = px.data.tips()
# Build App
app = JupyterDash(__name__)
app.layout = html.Div([
    html.H1("JupyterDash Demo"),
    dcc.Graph(id='graph'),
    html.Label([
        "colorscale",
        dcc.Dropdown(
            id='colorscale-dropdown', clearable=False,
            value='plasma', options=[
                {'label': c, 'value': c}
                for c in px.colors.named_colorscales()
            ])
    ]),
])
# Define callback to update graph
@app.callback(
    Output('graph', 'figure'),
    [Input("colorscale-dropdown", "value")]
)
def update_figure(colorscale):
    return px.scatter(
        df, x="total_bill", y="tip", color="size",
        color_continuous_scale=colorscale,
        render_mode="webgl", title="Tips"
    )
# Run app and display result inline in the notebook
app.run_server(mode='inline')
# Out:
# <ipython-input-3-04de55125734>:3: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# <ipython-input-3-04de55125734>:4: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
#app.run_server(mode='external')
# Out:
# Dash app running on http://127.0.0.1:8050/

# %%
import pandas as pd
df=pd.read_excel('Sample Data 1.xlsx')

# %%
df
# Out:
#     Fam. No. Publication no      Current assignees     Player Type  XX Rating  \
# 0          1     Reference9                    BYD             OEM          5
# 1          2    Reference10                    BYD             OEM          5
# 2          3   Reference330                  NIDEC         Suplier          5
# 3          4    Reference12                    BYD             OEM          4
# 4          5    Reference34                DAIMLER             OEM          4
# ..       ...            ...                    ...             ...        ...
# 95        96   Reference141  HONDA MOTOR  |HITACHI  OEM + Supplier          3
# 96        97   Reference147            HYUNDAI|KIA             OEM          3
# 97        98   Reference149            HYUNDAI|KIA             OEM          3
# 98        99   Reference150            HYUNDAI|KIA             OEM          3
# 99       100   Reference155            HYUNDAI|KIA             OEM          3
#
#     Sub-component                                   Uniqueness  \
# 0   MOTOR COOLING  Oil-cooled cooling system | Spraying device
# 1    MOTOR CASING                  Water-cooled cooling device
# 2         Winding                             Hairpin windings
# 3    MOTOR CASING                             Silencing spaces
# 4          STATOR                             Cooling channels
# ..            ...                                          ...
# 95  MOTOR COOLING                       Motor casing structure
# 96  MOTOR COOLING                          cooling oil chamber
# 97  MOTOR COOLING                      Motor cooling structure
# 98  MOTOR BEARING                             Ground structure
# 99  MOTOR COOLING      Oil immersion cooling system for stator
#
#                             Impact/Benefit AC/DC Motor Phase   ...  \
# 0               Improved cooling | Compact         NaN    NaN  ...
# 1                                  Compact         NaN    NaN  ...
# 2                         Improved Cooling          AC    NaN  ...
# 3       NVH | Improved Structural Strength         NaN    NaN  ...
# 4                         Improved cooling         NaN    NaN  ...
# ..                                     ...         ...    ...  ...
# 95                                 Compact         NaN    NaN  ...
# 96  Improved cooling | Improved efficiency         NaN    NaN  ...
# 97                        Improved cooling         NaN    NaN  ...
# 98            Improved Structural Strength         NaN  Three  ...
# 99                        Improved cooling          AC  Three  ...
#
#    Earliest priority date Application dates Unnamed: 27 Unnamed: 28  \
# 0              2019-04-15        2019-04-15         NaN         NaN
# 1              2019-04-15        2019-04-15         NaN         NaN
# 2              2019-10-31        2020-10-14         NaN         NaN
# 3              2019-07-16        2019-07-16         NaN         NaN
# 4              2018-08-08        2018-08-08         NaN         NaN
# ..                    ...               ...         ...         ...
# 95             2019-03-12        2020-03-10         NaN         NaN
# 96             2017-10-13        2017-11-29         NaN         NaN
# 97             2017-12-04        2018-10-04         NaN         NaN
# 98             2017-12-11        2018-08-14         NaN         NaN
# 99             2019-08-14        2020-06-11         NaN         NaN
#
#    Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33  Unnamed: 34
# 0          NaN         NaN         NaN         NaN         NaN          NaN
# 1          NaN         NaN         NaN         NaN         NaN          NaN
# 2          NaN         NaN         NaN         NaN         NaN          NaN
# 3          NaN         NaN         NaN         NaN         NaN          NaN
# 4          NaN         NaN         NaN         NaN         NaN          NaN
# ..         ...         ...         ...         ...         ...          ...
# 95         NaN         NaN         NaN         NaN         NaN          NaN
# 96         NaN         NaN         NaN         NaN         NaN          NaN
# 97         NaN         NaN         NaN         NaN         NaN          NaN
# 98         NaN         NaN         NaN         NaN         NaN          NaN
# 99         NaN         NaN         NaN         NaN         NaN          NaN
#
# [100 rows x 35 columns]

# %%
#Drop Unnamed Columns
df.drop(df.filter(regex="Unname"),axis=1, inplace=True)
df
# Out:
#     Fam. No. Publication no      Current assignees     Player Type  XX Rating  \
# 0          1     Reference9                    BYD             OEM          5
# 1          2    Reference10                    BYD             OEM          5
# 2          3   Reference330                  NIDEC         Suplier          5
# 3          4    Reference12                    BYD             OEM          4
# 4          5    Reference34                DAIMLER             OEM          4
# ..       ...            ...                    ...             ...        ...
# 95        96   Reference141  HONDA MOTOR  |HITACHI  OEM + Supplier          3
# 96        97   Reference147            HYUNDAI|KIA             OEM          3
# 97        98   Reference149            HYUNDAI|KIA             OEM          3
# 98        99   Reference150            HYUNDAI|KIA             OEM          3
# 99       100   Reference155            HYUNDAI|KIA             OEM          3
#
#     Sub-component                                   Uniqueness  \
# 0   MOTOR COOLING  Oil-cooled cooling system | Spraying device
# 1    MOTOR CASING                  Water-cooled cooling device
# 2         Winding                             Hairpin windings
# 3    MOTOR CASING                             Silencing spaces
# 4          STATOR                             Cooling channels
# ..            ...                                          ...
# 95  MOTOR COOLING                       Motor casing structure
# 96  MOTOR COOLING                          cooling oil chamber
# 97  MOTOR COOLING                      Motor cooling structure
# 98  MOTOR BEARING                             Ground structure
# 99  MOTOR COOLING      Oil immersion cooling system for stator
#
#                             Impact/Benefit AC/DC Motor Phase   ...  \
# 0               Improved cooling | Compact         NaN    NaN  ...
# 1                                  Compact         NaN    NaN  ...
# 2                         Improved Cooling          AC    NaN  ...
# 3       NVH | Improved Structural Strength         NaN    NaN  ...
# 4                         Improved cooling         NaN    NaN  ...
# ..                                     ...         ...    ...  ...
# 95                                 Compact         NaN    NaN  ...
# 96  Improved cooling | Improved efficiency         NaN    NaN  ...
# 97                        Improved cooling         NaN    NaN  ...
# 98            Improved Structural Strength         NaN  Three  ...
# 99                        Improved cooling          AC  Three  ...
#
#    Motor Position Family legal status Geography Count Cit Count Claim Count  \
# 0             NaN             GRANTED               1         0           1
# 1             NaN             PENDING               1         5           1
# 2             NaN             GRANTED               2         5           1
# 3             NaN             PENDING               1         6           1
# 4             NaN              LAPSED               1         4           1
# ..            ...                 ...             ...       ...         ...
# 95            NaN             PENDING               3         1           2
# 96            NaN             GRANTED               4        11           2
# 97            NaN             GRANTED               4        24           1
# 98            NaN             PENDING               4        17           2
# 99            NaN             GRANTED               3         2           2
#
#    Priority Country Overall Rating  \
# 0                CN           3.20
# 1                CN           2.85
# 2                FR           3.20
# 3                CN           3.05
# 4                DE           2.70
# ..              ...            ...
# 95               JP           2.65
# 96               KR           3.35
# 97               KR           3.20
# 98               KR           2.80
# 99               KR           2.90
#
#                                             Inventors Earliest priority date  \
# 0          WANG JIANXIN\nZOU XIAOSONG\nFANG ZHAOXIANG             2019-04-15
# 1          WANG JIANXIN\nZOU XIAOSONG\nFANG ZHAOXIANG             2019-04-15
# 2        LENOIR ROMARIC ([FR])\nBONNET VINCENT ([FR])             2019-10-31
# 3                                        HUA XIAOCONG             2019-07-16
# 4                               SCHULZE TORBEN ([DE])             2018-08-08
# ..                                                ...                    ...
# 95  YAZAKI MANABU ([JP])\nKASHIWABARA KEIICHIRO ([...             2019-03-12
# 96  DO SANG HWA ([KR])\nPARK JAE BUM ([KR])\nKIM K...             2017-10-13
# 97  SEOL WOO HYUNG ([KR])\nHA JAE WON ([KR])\nSEO ...             2017-12-04
# 98  KIM JUNG SHIK ([KR])\nCHO HYOUNGJUN ([KR])\nMO...             2017-12-11
# 99  LEE JAE HYEON ([KR])\nYIM JEONG BIN ([KR])\nKI...             2019-08-14
#
#     Application dates
# 0          2019-04-15
# 1          2019-04-15
# 2          2020-10-14
# 3          2019-07-16
# 4          2018-08-08
# ..                ...
# 95         2020-03-10
# 96         2017-11-29
# 97         2018-10-04
# 98         2018-08-14
# 99         2020-06-11
#
# [100 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['Fam. No.', 'Publication no', 'Current assignees', 'Player Type',
#        'XX Rating', 'Sub-component', 'Uniqueness', 'Impact/Benefit',
#        'AC/DC Motor', 'Phase ', 'MOTOR Type', 'Winding config', 'Hairpin',
#        'Flux', 'Cooling Passage', 'Coolant guide', 'Cooling Type',
#        'Motor Position', 'Family legal status', 'Geography Count', 'Cit Count',
#        'Claim Count', 'Priority Country', 'Overall Rating', 'Inventors',
#        'Earliest priority date', 'Application dates'],
#       dtype='object')

# %%
import plotly.express as px
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
# Load Data
# Build App
app = JupyterDash(__name__)
app.layout = html.Div([
    html.H1("JupyterDash Demo"),
    dcc.Graph(id='graph'),
    html.Label([
        "colorscale",
        dcc.Dropdown(
            id='colorscale-dropdown', clearable=False,
            value='plasma', options=[
                {'label': c, 'value': c}
                for c in px.colors.named_colorscales()
            ])
    ]),
])

# %%
import plotly.graph_objs as go
trace1 = go.Bar(x=df.index, y=df['Cit Count'])
trace2=go.Bar(x=df.index, y=df['Impact/Benefit'])

# %%
app = JupyterDash(__name__)
app.layout = html.Div(children=[
    html.H1(children='Sales Funnel Report'),
    html.Div(children='''National Sales Funnel Report.'''),
    dcc.Graph(
        id='example-graph',
        figure={
            'data': [trace1,trace2],
            'layout':
            go.Layout(title='Order Status by Customer', barmode='stack')
        })
])

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Dash app running on http://127.0.0.1:8050/
