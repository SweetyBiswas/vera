# %%
import pymysql
  

myconn = pymysql.connect(host = "localhost", user = "root",passwd = "sweety110", database='new', autocommit = True, charset = 'utf8mb4', cursorclass = pymysql.cursors.DictCursor)

cursor = myconn.cursor()

# %%
import pandas as pd
file='customer.csv'
df=pd.read_csv(file)
df.head()
# Out:
#    age  gender   review education purchased
# 0   30  Female  Average    School        No
# 1   68  Female     Poor        UG        No
# 2   70  Female     Good        PG        No
# 3   72  Female     Good        PG        No
# 4   16  Female  Average        UG        No

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:sweety110@localhost:3306/new', echo=False)

try:
    
    df.to_sql(name='customer',con=engine,index=False, if_exists='replace')
    print('Sucessfully written to Database!!!')

except Exception as e:
    
    print(e)
# Out:
# Sucessfully written to Database!!!

# %%
sql = "select * from customer"
cursor.execute(sql)

rows = cursor.fetchall()

print(rows)
# Out:
# [{'age': 30, 'gender': 'Female', 'review': 'Average', 'education': 'School', 'purchased': 'No'}, {'age': 68, 'gender': 'Female', 'review': 'Poor', 'education': 'UG', 'purchased': 'No'}, {'age': 70, 'gender': 'Female', 'review': 'Good', 'education': 'PG', 'purchased': 'No'}, {'age': 72, 'gender': 'Female', 'review': 'Good', 'education': 'PG', 'purchased': 'No'}, {'age': 16, 'gender': 'Female', 'review': 'Average', 'education': 'UG', 'purchased': 'No'}, {'age': 31, 'gender': 'Female', 'review': 'Average', 'education': 'School', 'purchased': 'Yes'}, {'age': 18, 'gender': 'Male', 'review': 'Good', 'education': 'School', 'purchased': 'No'}, {'age': 60, 'gender': 'Female', 'review': 'Poor', 'education': 'School', 'purchased': 'Yes'}, {'age': 65, 'gender': 'Female', 'review': 'Average', 'education': 'UG', 'purchased': 'No'}, {'age': 74, 'gender': 'Male', 'review': 'Good', 'education': 'UG', 'purchased': 'Yes'}, {'age': 98, 'gender': 'Female', 'review': 'Good', 'education': 'UG', 'purchased'
# ...

# %%
cursor.execute('''select * from customer where education = 'PG';''')
#cursor.execute(sql)

rows = cursor.fetchall()

print(rows)
# Out:
# [{'age': 70, 'gender': 'Female', 'review': 'Good', 'education': 'PG', 'purchased': 'No'}, {'age': 72, 'gender': 'Female', 'review': 'Good', 'education': 'PG', 'purchased': 'No'}, {'age': 15, 'gender': 'Male', 'review': 'Poor', 'education': 'PG', 'purchased': 'Yes'}, {'age': 97, 'gender': 'Male', 'review': 'Poor', 'education': 'PG', 'purchased': 'Yes'}, {'age': 32, 'gender': 'Male', 'review': 'Average', 'education': 'PG', 'purchased': 'No'}, {'age': 18, 'gender': 'Female', 'review': 'Poor', 'education': 'PG', 'purchased': 'Yes'}, {'age': 16, 'gender': 'Female', 'review': 'Average', 'education': 'PG', 'purchased': 'Yes'}, {'age': 53, 'gender': 'Female', 'review': 'Poor', 'education': 'PG', 'purchased': 'No'}, {'age': 69, 'gender': 'Female', 'review': 'Poor', 'education': 'PG', 'purchased': 'No'}, {'age': 89, 'gender': 'Female', 'review': 'Good', 'education': 'PG', 'purchased': 'Yes'}, {'age': 94, 'gender': 'Male', 'review': 'Average', 'education': 'PG', 'purchased': 'Yes'}, {'age': 76,
# ...

# %%
list=[]
for i in rows:
    
    age=i['age']
    gender=i['gender']
    review=i['review']
    education=i['education']
    purchased=i['purchased']
    
    list.append([age,gender,review,education,purchased])

# %%
import pandas as pd
df = pd.DataFrame(list,columns =['age','gender','review','education','purchased'])

# %%
df
# Out:
#     age  gender   review education purchased
# 0    70  Female     Good        PG        No
# 1    72  Female     Good        PG        No
# 2    15    Male     Poor        PG       Yes
# 3    97    Male     Poor        PG       Yes
# 4    32    Male  Average        PG        No
# 5    18  Female     Poor        PG       Yes
# 6    16  Female  Average        PG       Yes
# 7    53  Female     Poor        PG        No
# 8    69  Female     Poor        PG        No
# 9    89  Female     Good        PG       Yes
# 10   94    Male  Average        PG       Yes
# 11   76    Male     Poor        PG        No
# 12   23    Male     Good        PG       Yes
# 13   30  Female     Good        PG       Yes
# 14   27    Male     Poor        PG        No
# 15   61    Male     Poor        PG       Yes
# 16   64  Female     Poor        PG        No
# 17   38  Female     Good        PG       Yes

# %%
cursor.execute('''select schema_name from information_schema.schemata where schema_name = 'new';''')
#cursor.execute(sql)

rows = cursor.fetchall()

print(rows)
# Out:
# [{'SCHEMA_NAME': 'new'}]

# %%
for i in rows:
    for j in i.values():
        ex=j

# %%
data=input('Students Name: ')
if data==ex:
    print('exit')
else:
    sql=("""create database ({});""".format(data))
    cursor.execute(sql)
    print('database created')

    #('''create database data;''')


#sql=("""create database ({});""".format(data))


# student_name = input('Students Name: ')
#     student_age = input(' Students Age: ')
#     new_data = ("""INSERT INTO age_name (age, name)
#     VALUES ({},'{}');""".format(student_age, student_name))
#     cursor.execute(new_data)
# Out:
# Students Name: xyz
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-23-4805200df248> in <module>
#       4 else:
#       5     sql=("""create database ({});""".format(data))
# ----> 6     cursor.execute(sql)
#       7     print('database created')
#       8
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# ...

# %%
data='new'
if data==rows:
    print('exit')

# %%
CREATE TABLE [IF NOT EXISTS] tbl_name
    (create_definition,...)
    [table_options]
    [partition_options]

# %%
CREATE DATABASE [IF NOT EXISTS] database_name;

# %%
# import mysql.connector
# conn=mysql.connector.connect(host = "localhost", user = "root",passwd = "sweety110")
# cursor=conn.cursor()



import pymysql
  

myconn = pymysql.connect(host = "localhost", user = "root",passwd = "sweety110", autocommit = True, charset = 'utf8mb4', cursorclass = pymysql.cursors.DictCursor)

cursor = myconn.cursor() 

cursor.execute('show databases')
db=cursor.fetchall()

# database=input('enter database name')
# if (database,) in db:
#     print('exists')
# else:
#     cursor.execute("create database {}".format(database))
#     print('database created')
    
database=input('enter database name')    
for i in db:
    for j in i.values():
        if (database,)==j:
            print('database exists')
        else:
            
            cursor.execute("create database {}".format(database))
            print('database created')
        
            
cursor.close()
myconn.close()
# Out:
# enter database namenew
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-32-30c6b99b1d70> in <module>
#      29         else:
#      30
# ---> 31             cursor.execute("create database {}".format(database))
#      32             print('database created')
#      33
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# ...

# %%
pip install mysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql
  

myconn = pymysql.connect(host = "localhost", user = "root",passwd = "sweety110", autocommit = True, charset = 'utf8mb4', cursorclass = pymysql.cursors.DictCursor)

cursor = myconn.cursor() 

cursor.execute('show databases')
db=cursor.fetchall()

database=input('enter database name')
if (database,) in db:
    
    print('exists')
# Out:
# enter database nameb

# %%
db
# Out:
# [{'Database': 'data'},
#  {'Database': 'information_schema'},
#  {'Database': 'library'},
#  {'Database': 'librarymanagement'},
#  {'Database': 'lms'},
#  {'Database': 'lms1'},
#  {'Database': 'mysql'},
#  {'Database': 'new'},
#  {'Database': 'performance_schema'},
#  {'Database': 'sweety'},
#  {'Database': 'sys'}]

# %%
import pymysql
  
dbname = input('Please enter the name of database : ')
myconn = pymysql.connect(host = "localhost", user = "root",passwd = "sweety110", )

cursor = myconn.cursor() 
cursor.execute("CREATE DATABASE IF NOT EXISTS %s" %dbname)
# cursor.close()
# myconn.close()
# Out:
# Please enter the name of database : newt
# 1

# %%
import mysql.connector
      db = mysql.connector.connect(
      host = 'localhost',
      user = 'root',
      password = '',
      database=dbname, #providing name of database to connector
      )

      cursor = db.cursor()
      cursor.execute("CREATE TABLE IF NOT EXISTS %s (email VARCHAR(30),pwd 
      VARCHAR(20))" %dbname)
      cursor.close()
      db.close()}

# %%
import pymysql
  

myconn = pymysql.connect(host = "localhost", user = "root",passwd = "sweety110", database='new', autocommit = True, charset = 'utf8mb4', cursorclass = pymysql.cursors.DictCursor)

cursor = myconn.cursor() 
x='cars'
cursor.execute("select * from {}".format(x))


rows = cursor.fetchall()

print(rows)

# cursor.execute("create database {}".format(database))
# Out:
# [{'brand': 'Maruti', 'km_driven': 145500, 'fuel': 'Diesel', 'owner': 'First Owner', 'selling_price': 450000}, {'brand': 'Skoda', 'km_driven': 120000, 'fuel': 'Diesel', 'owner': 'Second Owner', 'selling_price': 370000}, {'brand': 'Honda', 'km_driven': 140000, 'fuel': 'Petrol', 'owner': 'Third Owner', 'selling_price': 158000}, {'brand': 'Hyundai', 'km_driven': 127000, 'fuel': 'Diesel', 'owner': 'First Owner', 'selling_price': 225000}, {'brand': 'Maruti', 'km_driven': 120000, 'fuel': 'Petrol', 'owner': 'First Owner', 'selling_price': 130000}, {'brand': 'Hyundai', 'km_driven': 45000, 'fuel': 'Petrol', 'owner': 'First Owner', 'selling_price': 440000}, {'brand': 'Maruti', 'km_driven': 175000, 'fuel': 'LPG', 'owner': 'First Owner', 'selling_price': 96000}, {'brand': 'Maruti', 'km_driven': 5000, 'fuel': 'Petrol', 'owner': 'Second Owner', 'selling_price': 45000}, {'brand': 'Toyota', 'km_driven': 90000, 'fuel': 'Diesel', 'owner': 'First Owner', 'selling_price': 350000}, {'brand': 'Ford', 'km_d
# ...
